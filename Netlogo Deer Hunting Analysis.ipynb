# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Execution and Analysis of Model

# %% [markdown]
# ### Altering the number of hunters and their harvest probability

# %% [markdown]
# #### Large number of hunters and high harvest probability

# %%
huntP_probP_run1 = pd.read_csv("data_collection/hunt+_prob+_run1.csv")
huntP_probP_run1 = huntP_probP_run1[huntP_probP_run1.year < 5]
huntP_probP_run2 = pd.read_csv("data_collection/hunt+_prob+_run2.csv")
huntP_probP_run2 = huntP_probP_run2[huntP_probP_run2.year < 5]
huntP_probP_run3 = pd.read_csv("data_collection/hunt+_prob+_run3.csv")
huntP_probP_run3 = huntP_probP_run3[huntP_probP_run3.year < 5]
huntP_probP_run4 = pd.read_csv("data_collection/hunt+_prob+_run4.csv")
huntP_probP_run4 = huntP_probP_run4[huntP_probP_run4.year < 5]
huntP_probP_run5 = pd.read_csv("data_collection/hunt+_prob+_run5.csv")
huntP_probP_run5 = huntP_probP_run5[huntP_probP_run5.year < 5]

# %%
# view first run
huntP_probP_run1
# Out:
#      year         day  cumulative_days  male_deer_population  \
# 0       0    0.000000         0.000000                200000
# 1       0    2.067825         2.067825                200000
# 2       0    4.135649         4.135649                200000
# 3       0    6.203474         6.203474                200000
# 4       0    8.271299         8.271299                200000
# ..    ...         ...              ...                   ...
# 880     4  355.665840      1819.685691                 26000
# 881     4  357.733664      1821.753515                 26000
# 882     4  359.801489      1823.821340                 26000
# 883     4  361.869313      1825.889165                 26000
# 884     4  363.937138      1827.956989                 26000
#
#      female_deer_population  total_deer_population  number_of_hunters  \
# 0                    200000                 400000             200000
# 1                    200000                 400000                  0
# ...

# %%
# view second run
huntP_probP_run2
# Out:
#      year         day  cumulative_days  male_deer_population  \
# 0       0    0.000000         0.000000                200000
# 1       0    2.067825         2.067825                200000
# 2       0    4.135649         4.135649                200000
# 3       0    6.203474         6.203474                200000
# 4       0    8.271299         8.271299                200000
# ..    ...         ...              ...                   ...
# 880     4  355.665840      1819.685691                 35000
# 881     4  357.733664      1821.753515                 35000
# 882     4  359.801489      1823.821340                 35000
# 883     4  361.869313      1825.889165                 35000
# 884     4  363.937138      1827.956989                 35000
#
#      female_deer_population  total_deer_population  number_of_hunters  \
# 0                    200000                 400000             200000
# 1                    200000                 400000                  0
# ...

# %%
# view third run
huntP_probP_run3
# Out:
#      year         day  cumulative_days  male_deer_population  \
# 0       0    0.000000         0.000000                200000
# 1       0    2.067825         2.067825                200000
# 2       0    4.135649         4.135649                200000
# 3       0    6.203474         6.203474                200000
# 4       0    8.271299         8.271299                200000
# ..    ...         ...              ...                   ...
# 880     4  355.665840      1819.685691                 38000
# 881     4  357.733664      1821.753515                 38000
# 882     4  359.801489      1823.821340                 38000
# 883     4  361.869313      1825.889165                 38000
# 884     4  363.937138      1827.956989                 38000
#
#      female_deer_population  total_deer_population  number_of_hunters  \
# 0                    200000                 400000             200000
# 1                    200000                 400000                  0
# ...

# %%
# view fourth run
huntP_probP_run4
# Out:
#      year         day  cumulative_days  male_deer_population  \
# 0       0    0.000000         0.000000                200000
# 1       0    2.067825         2.067825                200000
# 2       0    4.135649         4.135649                200000
# 3       0    6.203474         6.203474                200000
# 4       0    8.271299         8.271299                200000
# ..    ...         ...              ...                   ...
# 880     4  355.665840      1819.685691                 35000
# 881     4  357.733664      1821.753515                 35000
# 882     4  359.801489      1823.821340                 35000
# 883     4  361.869313      1825.889165                 35000
# 884     4  363.937138      1827.956989                 35000
#
#      female_deer_population  total_deer_population  number_of_hunters  \
# 0                    200000                 400000             200000
# 1                    200000                 400000                  0
# ...

# %%
# view fifth run
huntP_probP_run5
# Out:
#      year         day  cumulative_days  male_deer_population  \
# 0       0    0.000000         0.000000                200000
# 1       0    2.067825         2.067825                200000
# 2       0    4.135649         4.135649                200000
# 3       0    6.203474         6.203474                200000
# 4       0    8.271299         8.271299                200000
# ..    ...         ...              ...                   ...
# 880     4  355.665840      1819.685691                 26000
# 881     4  357.733664      1821.753515                 26000
# 882     4  359.801489      1823.821340                 26000
# 883     4  361.869313      1825.889165                 26000
# 884     4  363.937138      1827.956989                 26000
#
#      female_deer_population  total_deer_population  number_of_hunters  \
# 0                    200000                 400000             200000
# 1                    200000                 400000                  0
# ...

# %% [markdown]
# #### Small number of hunters and low harvest probability

# %%
huntM_probM_run1 = pd.read_csv("data_collection/hunt-_prob-_run1.csv")
huntM_probM_run1 = huntM_probM_run1[huntM_probM_run1.year < 5]
huntM_probM_run2 = pd.read_csv("data_collection/hunt-_prob-_run2.csv")
huntM_probM_run2 = huntM_probM_run2[huntM_probM_run2.year < 5]
huntM_probM_run3 = pd.read_csv("data_collection/hunt-_prob-_run3.csv")
huntM_probM_run3 = huntM_probM_run3[huntM_probM_run3.year < 5]
huntM_probM_run4 = pd.read_csv("data_collection/hunt-_prob-_run4.csv")
huntM_probM_run4 = huntM_probM_run4[huntM_probM_run4.year < 5]
huntM_probM_run5 = pd.read_csv("data_collection/hunt-_prob-_run5.csv")
huntM_probM_run5 = huntM_probM_run5[huntM_probM_run5.year < 5]

# %%
# view first run
huntM_probM_run1
# Out:
#      year         day  cumulative_days  male_deer_population  \
# 0       0    0.000000         0.000000                200000
# 1       0    2.067825         2.067825                200000
# 2       0    4.135649         4.135649                200000
# 3       0    6.203474         6.203474                200000
# 4       0    8.271299         8.271299                200000
# ..    ...         ...              ...                   ...
# 880     4  355.665840      1819.685691                503000
# 881     4  357.733664      1821.753515                503000
# 882     4  359.801489      1823.821340                503000
# 883     4  361.869313      1825.889165                503000
# 884     4  363.937138      1827.956989                503000
#
#      female_deer_population  total_deer_population  number_of_hunters  \
# 0                    200000                 400000              50000
# 1                    200000                 400000                  0
# ...

# %%
# view second run
huntM_probM_run2
# Out:
#      year         day  cumulative_days  male_deer_population  \
# 0       0    0.000000         0.000000                200000
# 1       0    2.067825         2.067825                200000
# 2       0    4.135649         4.135649                200000
# 3       0    6.203474         6.203474                200000
# 4       0    8.271299         8.271299                200000
# ..    ...         ...              ...                   ...
# 880     4  355.665840      1819.685691                446000
# 881     4  357.733664      1821.753515                446000
# 882     4  359.801489      1823.821340                446000
# 883     4  361.869313      1825.889165                446000
# 884     4  363.937138      1827.956989                446000
#
#      female_deer_population  total_deer_population  number_of_hunters  \
# 0                    200000                 400000              50000
# 1                    200000                 400000                  0
# ...

# %%
# view third run
huntM_probM_run3
# Out:
#      year         day  cumulative_days  male_deer_population  \
# 0       0    0.000000         0.000000                200000
# 1       0    2.067825         2.067825                200000
# 2       0    4.135649         4.135649                200000
# 3       0    6.203474         6.203474                200000
# 4       0    8.271299         8.271299                200000
# ..    ...         ...              ...                   ...
# 880     4  355.665840      1819.685691                507000
# 881     4  357.733664      1821.753515                507000
# 882     4  359.801489      1823.821340                507000
# 883     4  361.869313      1825.889165                507000
# 884     4  363.937138      1827.956989                507000
#
#      female_deer_population  total_deer_population  number_of_hunters  \
# 0                    200000                 400000              50000
# 1                    200000                 400000                  0
# ...

# %%
# view fourth run
huntM_probM_run4
# Out:
#      year         day  cumulative_days  male_deer_population  \
# 0       0    0.000000         0.000000                200000
# 1       0    2.067825         2.067825                200000
# 2       0    4.135649         4.135649                200000
# 3       0    6.203474         6.203474                200000
# 4       0    8.271299         8.271299                200000
# ..    ...         ...              ...                   ...
# 880     4  355.665840      1819.685691                490000
# 881     4  357.733664      1821.753515                490000
# 882     4  359.801489      1823.821340                490000
# 883     4  361.869313      1825.889165                490000
# 884     4  363.937138      1827.956989                490000
#
#      female_deer_population  total_deer_population  number_of_hunters  \
# 0                    200000                 400000              50000
# 1                    200000                 400000                  0
# ...

# %%
# view fifth run
huntM_probM_run5
# Out:
#      year         day  cumulative_days  male_deer_population  \
# 0       0    0.000000         0.000000                200000
# 1       0    2.067825         2.067825                200000
# 2       0    4.135649         4.135649                200000
# 3       0    6.203474         6.203474                200000
# 4       0    8.271299         8.271299                200000
# ..    ...         ...              ...                   ...
# 880     4  355.665840      1819.685691                389000
# 881     4  357.733664      1821.753515                389000
# 882     4  359.801489      1823.821340                389000
# 883     4  361.869313      1825.889165                389000
# 884     4  363.937138      1827.956989                389000
#
#      female_deer_population  total_deer_population  number_of_hunters  \
# 0                    200000                 400000              50000
# 1                    200000                 400000                  0
# ...

# %% [markdown]
# #### Small number of hunters and high harvest probability

# %%
huntM_probP_run1 = pd.read_csv("data_collection/hunt-_prob+_run1.csv")
huntM_probP_run1 = huntM_probP_run1[huntM_probP_run1.year < 5]
huntM_probP_run2 = pd.read_csv("data_collection/hunt-_prob+_run2.csv")
huntM_probP_run2 = huntM_probP_run2[huntM_probP_run2.year < 5]
huntM_probP_run3 = pd.read_csv("data_collection/hunt-_prob+_run3.csv")
huntM_probP_run3 = huntM_probP_run3[huntM_probP_run3.year < 5]
huntM_probP_run4 = pd.read_csv("data_collection/hunt-_prob+_run4.csv")
huntM_probP_run4 = huntM_probP_run4[huntM_probP_run4.year < 5]
huntM_probP_run5 = pd.read_csv("data_collection/hunt-_prob+_run5.csv")
huntM_probP_run5 = huntM_probP_run5[huntM_probP_run5.year < 5]

# %%
# view first run
huntM_probP_run1
# Out:
#      year         day  cumulative_days  male_deer_population  \
# 0       0    0.000000         0.000000                200000
# 1       0    2.067825         2.067825                200000
# 2       0    4.135649         4.135649                199000
# 3       0    6.203474         6.203474                199000
# 4       0    8.271299         8.271299                199000
# ..    ...         ...              ...                   ...
# 880     4  355.665840      1819.685691                289000
# 881     4  357.733664      1821.753515                289000
# 882     4  359.801489      1823.821340                289000
# 883     4  361.869313      1825.889165                289000
# 884     4  363.937138      1827.956989                289000
#
#      female_deer_population  total_deer_population  number_of_hunters  \
# 0                    200000                 400000              50000
# 1                    200000                 400000                  0
# ...

# %%
# view second run
huntM_probP_run2
# Out:
#      year         day  cumulative_days  male_deer_population  \
# 0       0    0.000000         0.000000                200000
# 1       0    2.067825         2.067825                200000
# 2       0    4.135649         4.135649                200000
# 3       0    6.203474         6.203474                200000
# 4       0    8.271299         8.271299                200000
# ..    ...         ...              ...                   ...
# 880     4  355.665840      1819.685691                275000
# 881     4  357.733664      1821.753515                275000
# 882     4  359.801489      1823.821340                275000
# 883     4  361.869313      1825.889165                275000
# 884     4  363.937138      1827.956989                275000
#
#      female_deer_population  total_deer_population  number_of_hunters  \
# 0                    200000                 400000              50000
# 1                    200000                 400000                  0
# ...

# %%
# view third run
huntM_probP_run3
# Out:
#      year         day  cumulative_days  male_deer_population  \
# 0       0    0.000000         0.000000                200000
# 1       0    2.067825         2.067825                200000
# 2       0    4.135649         4.135649                200000
# 3       0    6.203474         6.203474                200000
# 4       0    8.271299         8.271299                200000
# ..    ...         ...              ...                   ...
# 880     4  355.665840      1819.685691                289000
# 881     4  357.733664      1821.753515                289000
# 882     4  359.801489      1823.821340                289000
# 883     4  361.869313      1825.889165                289000
# 884     4  363.937138      1827.956989                289000
#
#      female_deer_population  total_deer_population  number_of_hunters  \
# 0                    200000                 400000              50000
# 1                    200000                 400000                  0
# ...

# %%
# view fourth run
huntM_probP_run4
# Out:
#      year         day  cumulative_days  male_deer_population  \
# 0       0    0.000000         0.000000                200000
# 1       0    2.067825         2.067825                200000
# 2       0    4.135649         4.135649                200000
# 3       0    6.203474         6.203474                200000
# 4       0    8.271299         8.271299                200000
# ..    ...         ...              ...                   ...
# 880     4  355.665840      1819.685691                275000
# 881     4  357.733664      1821.753515                275000
# 882     4  359.801489      1823.821340                275000
# 883     4  361.869313      1825.889165                275000
# 884     4  363.937138      1827.956989                275000
#
#      female_deer_population  total_deer_population  number_of_hunters  \
# 0                    200000                 400000              50000
# 1                    200000                 400000                  0
# ...

# %%
# view fifth run
huntM_probP_run5
# Out:
#      year         day  cumulative_days  male_deer_population  \
# 0       0    0.000000         0.000000                200000
# 1       0    2.067825         2.067825                200000
# 2       0    4.135649         4.135649                200000
# 3       0    6.203474         6.203474                200000
# 4       0    8.271299         8.271299                200000
# ..    ...         ...              ...                   ...
# 880     4  355.665840      1819.685691                302000
# 881     4  357.733664      1821.753515                302000
# 882     4  359.801489      1823.821340                302000
# 883     4  361.869313      1825.889165                302000
# 884     4  363.937138      1827.956989                302000
#
#      female_deer_population  total_deer_population  number_of_hunters  \
# 0                    200000                 400000              50000
# 1                    200000                 400000                  0
# ...

# %% [markdown]
# #### Large number of hunters and low harvest probability

# %%
huntP_probM_run1 = pd.read_csv("data_collection/hunt+_prob-_run1.csv")
huntP_probM_run1 = huntP_probM_run1[huntP_probM_run1.year < 5]
huntP_probM_run2 = pd.read_csv("data_collection/hunt+_prob-_run2.csv")
huntP_probM_run2 = huntP_probM_run2[huntP_probM_run2.year < 5]
huntP_probM_run3 = pd.read_csv("data_collection/hunt+_prob-_run3.csv")
huntP_probM_run3 = huntP_probM_run3[huntP_probM_run3.year < 5]
huntP_probM_run4 = pd.read_csv("data_collection/hunt+_prob-_run4.csv")
huntP_probM_run4 = huntP_probM_run4[huntP_probM_run4.year < 5]
huntP_probM_run5 = pd.read_csv("data_collection/hunt+_prob-_run5.csv")
huntP_probM_run5 = huntP_probM_run5[huntP_probM_run5.year < 5]

# %%
# view first run
huntP_probM_run1
# Out:
#      year         day  cumulative_days  male_deer_population  \
# 0       0    0.000000         0.000000                200000
# 1       0    2.067825         2.067825                200000
# 2       0    4.135649         4.135649                200000
# 3       0    6.203474         6.203474                200000
# 4       0    8.271299         8.271299                200000
# ..    ...         ...              ...                   ...
# 880     4  355.665840      1819.685691                219000
# 881     4  357.733664      1821.753515                219000
# 882     4  359.801489      1823.821340                219000
# 883     4  361.869313      1825.889165                219000
# 884     4  363.937138      1827.956989                219000
#
#      female_deer_population  total_deer_population  number_of_hunters  \
# 0                    200000                 400000             200000
# 1                    200000                 400000                  0
# ...

# %%
# view second run
huntP_probM_run2
# Out:
#      year         day  cumulative_days  male_deer_population  \
# 0       0    0.000000         0.000000                200000
# 1       0    2.067825         2.067825                200000
# 2       0    4.135649         4.135649                200000
# 3       0    6.203474         6.203474                200000
# 4       0    8.271299         8.271299                200000
# ..    ...         ...              ...                   ...
# 880     4  355.665840      1819.685691                207000
# 881     4  357.733664      1821.753515                207000
# 882     4  359.801489      1823.821340                207000
# 883     4  361.869313      1825.889165                207000
# 884     4  363.937138      1827.956989                207000
#
#      female_deer_population  total_deer_population  number_of_hunters  \
# 0                    200000                 400000             200000
# 1                    200000                 400000                  0
# ...

# %%
# view third run
huntP_probM_run3
# Out:
#      year         day  cumulative_days  male_deer_population  \
# 0       0    0.000000         0.000000                200000
# 1       0    2.067825         2.067825                200000
# 2       0    4.135649         4.135649                200000
# 3       0    6.203474         6.203474                200000
# 4       0    8.271299         8.271299                200000
# ..    ...         ...              ...                   ...
# 880     4  355.665840      1819.685691                213000
# 881     4  357.733664      1821.753515                213000
# 882     4  359.801489      1823.821340                213000
# 883     4  361.869313      1825.889165                213000
# 884     4  363.937138      1827.956989                213000
#
#      female_deer_population  total_deer_population  number_of_hunters  \
# 0                    200000                 400000             200000
# 1                    200000                 400000                  0
# ...

# %%
# view fourth run
huntP_probM_run4
# Out:
#      year         day  cumulative_days  male_deer_population  \
# 0       0    0.000000         0.000000                200000
# 1       0    2.067825         2.067825                200000
# 2       0    4.135649         4.135649                200000
# 3       0    6.203474         6.203474                200000
# 4       0    8.271299         8.271299                200000
# ..    ...         ...              ...                   ...
# 880     4  355.665840      1819.685691                244000
# 881     4  357.733664      1821.753515                244000
# 882     4  359.801489      1823.821340                244000
# 883     4  361.869313      1825.889165                244000
# 884     4  363.937138      1827.956989                244000
#
#      female_deer_population  total_deer_population  number_of_hunters  \
# 0                    200000                 400000             200000
# 1                    200000                 400000                  0
# ...

# %%
# view fifth run
huntP_probM_run5
# Out:
#      year         day  cumulative_days  male_deer_population  \
# 0       0    0.000000         0.000000                200000
# 1       0    2.067825         2.067825                200000
# 2       0    4.135649         4.135649                200000
# 3       0    6.203474         6.203474                200000
# 4       0    8.271299         8.271299                200000
# ..    ...         ...              ...                   ...
# 880     4  355.665840      1819.685691                240000
# 881     4  357.733664      1821.753515                240000
# 882     4  359.801489      1823.821340                240000
# 883     4  361.869313      1825.889165                240000
# 884     4  363.937138      1827.956989                240000
#
#      female_deer_population  total_deer_population  number_of_hunters  \
# 0                    200000                 400000             200000
# 1                    200000                 400000                  0
# ...

# %% [markdown]
# #### Graph of results

# %%
# plot of the total deer population over time for all the five runs and for each parameter change
plt.rcParams["figure.figsize"] = [10, 10]
plt.rcParams["figure.autolayout"] = True

fig, ax = plt.subplots(2, 2)
fig.tight_layout()

ax[0, 0].plot(huntP_probP_run1['cumulative_days'], huntP_probP_run1['total_deer_population'], alpha=0.4, color='red', label='Run 1')
ax[0, 0].plot(huntP_probP_run2['cumulative_days'], huntP_probP_run2['total_deer_population'], alpha=0.4, color='blue', label='Run 2')
ax[0, 0].plot(huntP_probP_run3['cumulative_days'], huntP_probP_run3['total_deer_population'], alpha=0.4, color='green', label='Run 3')
ax[0, 0].plot(huntP_probP_run4['cumulative_days'], huntP_probP_run4['total_deer_population'], alpha=0.4, color='yellow', label='Run 4')
ax[0, 0].plot(huntP_probP_run5['cumulative_days'], huntP_probP_run5['total_deer_population'], alpha=0.4, color='black', label='Run 5')
ax[0, 0].set_xlabel('Day')
ax[0, 0].set_ylabel('Total Deer Population')
ax[0, 0].set_title("Large number of hunters & high harvest probability")


ax[1, 0].plot(huntP_probM_run1['cumulative_days'], huntP_probM_run1['total_deer_population'], alpha=0.4, color='red', label='Run 1')
ax[1, 0].plot(huntP_probM_run2['cumulative_days'], huntP_probM_run2['total_deer_population'], alpha=0.4, color='blue', label='Run 2')
ax[1, 0].plot(huntP_probM_run3['cumulative_days'], huntP_probM_run3['total_deer_population'], alpha=0.4, color='green', label='Run 3')
ax[1, 0].plot(huntP_probM_run4['cumulative_days'], huntP_probM_run4['total_deer_population'], alpha=0.4, color='yellow', label='Run 4')
ax[1, 0].plot(huntP_probM_run5['cumulative_days'], huntP_probM_run5['total_deer_population'], alpha=0.4, color='black', label='Run 5')
ax[1, 0].set_xlabel('Day')
ax[1, 0].set_ylabel('Total Deer Population')
ax[1, 0].set_title("Large number of hunters & low harvest probability")

ax[0, 1].plot(huntM_probM_run1['cumulative_days'], huntM_probM_run1['total_deer_population'], alpha=0.4, color='red', label='Run 1')
ax[0, 1].plot(huntM_probM_run2['cumulative_days'], huntM_probM_run2['total_deer_population'], alpha=0.4, color='blue', label='Run 2')
ax[0, 1].plot(huntM_probM_run3['cumulative_days'], huntM_probM_run3['total_deer_population'], alpha=0.4, color='green', label='Run 3')
ax[0, 1].plot(huntM_probM_run4['cumulative_days'], huntM_probM_run4['total_deer_population'], alpha=0.4, color='yellow', label='Run 4')
ax[0, 1].plot(huntM_probM_run5['cumulative_days'], huntM_probM_run5['total_deer_population'], alpha=0.4, color='black', label='Run 5')
ax[0, 1].set_xlabel('Day')
ax[0, 1].set_ylabel('Total Deer Population')
ax[0, 1].set_title("Small number of hunters & low harvest probability")

ax[1, 1].plot(huntM_probP_run1['cumulative_days'], huntM_probP_run1['total_deer_population'], alpha=0.4, color='red', label='Run 1')
ax[1, 1].plot(huntM_probP_run2['cumulative_days'], huntM_probP_run2['total_deer_population'], alpha=0.4, color='blue', label='Run 2')
ax[1, 1].plot(huntM_probP_run3['cumulative_days'], huntM_probP_run3['total_deer_population'], alpha=0.4, color='green', label='Run 3')
ax[1, 1].plot(huntM_probP_run4['cumulative_days'], huntM_probP_run4['total_deer_population'], alpha=0.4, color='yellow', label='Run 4')
ax[1, 1].plot(huntM_probP_run5['cumulative_days'], huntM_probP_run5['total_deer_population'], alpha=0.4, color='black', label='Run 5')
ax[1, 1].set_xlabel('Day')
ax[1, 1].set_ylabel('Total Deer Population')
ax[1, 1].set_title("Small number of hunters & high harvest probability")


ax[0, 0].legend()
ax[0, 1].legend()
ax[1, 0].legend()
ax[1, 1].legend()

plt.show()

# %%
# plot of the total deer hit over time for all the five runs and for each parameter change
plt.rcParams["figure.figsize"] = [10, 10]
plt.rcParams["figure.autolayout"] = True

fig, ax = plt.subplots(2, 2)
fig.tight_layout()

ax[0, 0].plot(huntP_probP_run1['cumulative_days'], huntP_probP_run1['number_of_deer_hit'], alpha=0.4, color='red', label='Run 1')
ax[0, 0].plot(huntP_probP_run2['cumulative_days'], huntP_probP_run2['number_of_deer_hit'], alpha=0.4, color='blue', label='Run 2')
ax[0, 0].plot(huntP_probP_run3['cumulative_days'], huntP_probP_run3['number_of_deer_hit'], alpha=0.4, color='green', label='Run 3')
ax[0, 0].plot(huntP_probP_run4['cumulative_days'], huntP_probP_run4['number_of_deer_hit'], alpha=0.4, color='yellow', label='Run 4')
ax[0, 0].plot(huntP_probP_run5['cumulative_days'], huntP_probP_run5['number_of_deer_hit'], alpha=0.4, color='black', label='Run 5')
ax[0, 0].set_xlabel('Day')
ax[0, 0].set_ylabel('Deer Hit')
ax[0, 0].set_title("Large number of hunters & high harvest probability")


ax[1, 0].plot(huntP_probM_run1['cumulative_days'], huntP_probM_run1['number_of_deer_hit'], alpha=0.4, color='red', label='Run 1')
ax[1, 0].plot(huntP_probM_run2['cumulative_days'], huntP_probM_run2['number_of_deer_hit'], alpha=0.4, color='blue', label='Run 2')
ax[1, 0].plot(huntP_probM_run3['cumulative_days'], huntP_probM_run3['number_of_deer_hit'], alpha=0.4, color='green', label='Run 3')
ax[1, 0].plot(huntP_probM_run4['cumulative_days'], huntP_probM_run4['number_of_deer_hit'], alpha=0.4, color='yellow', label='Run 4')
ax[1, 0].plot(huntP_probM_run5['cumulative_days'], huntP_probM_run5['number_of_deer_hit'], alpha=0.4, color='black', label='Run 5')
ax[1, 0].set_xlabel('Day')
ax[1, 0].set_ylabel('Deer Hit')
ax[1, 0].set_title("Large number of hunters & low harvest probability")

ax[0, 1].plot(huntM_probM_run1['cumulative_days'], huntM_probM_run1['number_of_deer_hit'], alpha=0.4, color='red', label='Run 1')
ax[0, 1].plot(huntM_probM_run2['cumulative_days'], huntM_probM_run2['number_of_deer_hit'], alpha=0.4, color='blue', label='Run 2')
ax[0, 1].plot(huntM_probM_run3['cumulative_days'], huntM_probM_run3['number_of_deer_hit'], alpha=0.4, color='green', label='Run 3')
ax[0, 1].plot(huntM_probM_run4['cumulative_days'], huntM_probM_run4['number_of_deer_hit'], alpha=0.4, color='yellow', label='Run 4')
ax[0, 1].plot(huntM_probM_run5['cumulative_days'], huntM_probM_run5['number_of_deer_hit'], alpha=0.4, color='black', label='Run 5')
ax[0, 1].set_xlabel('Day')
ax[0, 1].set_ylabel('Deer Hit')
ax[0, 1].set_title("Small number of hunters & low harvest probability")

ax[1, 1].plot(huntM_probP_run1['cumulative_days'], huntM_probP_run1['number_of_deer_hit'], alpha=0.4, color='red', label='Run 1')
ax[1, 1].plot(huntM_probP_run2['cumulative_days'], huntM_probP_run2['number_of_deer_hit'], alpha=0.4, color='blue', label='Run 2')
ax[1, 1].plot(huntM_probP_run3['cumulative_days'], huntM_probP_run3['number_of_deer_hit'], alpha=0.4, color='green', label='Run 3')
ax[1, 1].plot(huntM_probP_run4['cumulative_days'], huntM_probP_run4['number_of_deer_hit'], alpha=0.4, color='yellow', label='Run 4')
ax[1, 1].plot(huntM_probP_run5['cumulative_days'], huntM_probP_run5['number_of_deer_hit'], alpha=0.4, color='black', label='Run 5')
ax[1, 1].set_xlabel('Day')
ax[1, 1].set_ylabel('Deer Hit')
ax[1, 1].set_title("Small number of hunters & high harvest probability")


ax[0, 0].legend()
ax[0, 1].legend()
ax[1, 0].legend()
ax[1, 1].legend()

plt.show()

# %%
# plot of the total harvested deer over time for all the five runs and for each parameter change
plt.rcParams["figure.figsize"] = [10, 10]
plt.rcParams["figure.autolayout"] = True

fig, ax = plt.subplots(2, 2)
fig.tight_layout()

ax[0, 0].plot(huntP_probP_run1['cumulative_days'], huntP_probP_run1['harvested_deer'], alpha=0.4, color='red', label='Run 1')
ax[0, 0].plot(huntP_probP_run2['cumulative_days'], huntP_probP_run2['harvested_deer'], alpha=0.4, color='blue', label='Run 2')
ax[0, 0].plot(huntP_probP_run3['cumulative_days'], huntP_probP_run3['harvested_deer'], alpha=0.4, color='green', label='Run 3')
ax[0, 0].plot(huntP_probP_run4['cumulative_days'], huntP_probP_run4['harvested_deer'], alpha=0.4, color='yellow', label='Run 4')
ax[0, 0].plot(huntP_probP_run5['cumulative_days'], huntP_probP_run5['harvested_deer'], alpha=0.4, color='black', label='Run 5')
ax[0, 0].set_xlabel('Day')
ax[0, 0].set_ylabel('Harvested Deer')
ax[0, 0].set_title("Large number of hunters & high harvest probability")


ax[1, 0].plot(huntP_probM_run1['cumulative_days'], huntP_probM_run1['harvested_deer'], alpha=0.4, color='red', label='Run 1')
ax[1, 0].plot(huntP_probM_run2['cumulative_days'], huntP_probM_run2['harvested_deer'], alpha=0.4, color='blue', label='Run 2')
ax[1, 0].plot(huntP_probM_run3['cumulative_days'], huntP_probM_run3['harvested_deer'], alpha=0.4, color='green', label='Run 3')
ax[1, 0].plot(huntP_probM_run4['cumulative_days'], huntP_probM_run4['harvested_deer'], alpha=0.4, color='yellow', label='Run 4')
ax[1, 0].plot(huntP_probM_run5['cumulative_days'], huntP_probM_run5['harvested_deer'], alpha=0.4, color='black', label='Run 5')
ax[1, 0].set_xlabel('Day')
ax[1, 0].set_ylabel('Harvested Deer')
ax[1, 0].set_title("Large number of hunters & low harvest probability")

ax[0, 1].plot(huntM_probM_run1['cumulative_days'], huntM_probM_run1['harvested_deer'], alpha=0.4, color='red', label='Run 1')
ax[0, 1].plot(huntM_probM_run2['cumulative_days'], huntM_probM_run2['harvested_deer'], alpha=0.4, color='blue', label='Run 2')
ax[0, 1].plot(huntM_probM_run3['cumulative_days'], huntM_probM_run3['harvested_deer'], alpha=0.4, color='green', label='Run 3')
ax[0, 1].plot(huntM_probM_run4['cumulative_days'], huntM_probM_run4['harvested_deer'], alpha=0.4, color='yellow', label='Run 4')
ax[0, 1].plot(huntM_probM_run5['cumulative_days'], huntM_probM_run5['harvested_deer'], alpha=0.4, color='black', label='Run 5')
ax[0, 1].set_xlabel('Day')
ax[0, 1].set_ylabel('Harvested Deer')
ax[0, 1].set_title("Small number of hunters & low harvest probability")

ax[1, 1].plot(huntM_probP_run1['cumulative_days'], huntM_probP_run1['harvested_deer'], alpha=0.4, color='red', label='Run 1')
ax[1, 1].plot(huntM_probP_run2['cumulative_days'], huntM_probP_run2['harvested_deer'], alpha=0.4, color='blue', label='Run 2')
ax[1, 1].plot(huntM_probP_run3['cumulative_days'], huntM_probP_run3['harvested_deer'], alpha=0.4, color='green', label='Run 3')
ax[1, 1].plot(huntM_probP_run4['cumulative_days'], huntM_probP_run4['harvested_deer'], alpha=0.4, color='yellow', label='Run 4')
ax[1, 1].plot(huntM_probP_run5['cumulative_days'], huntM_probP_run5['harvested_deer'], alpha=0.4, color='black', label='Run 5')
ax[1, 1].set_xlabel('Day')
ax[1, 1].set_ylabel('Harvested Deer')
ax[1, 1].set_title("Small number of hunters & high harvest probability")


ax[0, 0].legend()
ax[0, 1].legend()
ax[1, 0].legend()
ax[1, 1].legend()


plt.show()

# %% [markdown]
# ## Verification (Pennsylvania data)

# %% [markdown]
# ### 2019-2020

# %%
penn_20_run_1 = pd.read_csv("2019-2020/penn_20_run_1.csv")
penn_20_run_2 = pd.read_csv("2019-2020/penn_20_run_2.csv")
penn_20_run_3 = pd.read_csv("2019-2020/penn_20_run_3.csv")
penn_20_run_4 = pd.read_csv("2019-2020/penn_20_run_4.csv")
penn_20_run_5 = pd.read_csv("2019-2020/penn_20_run_5.csv")

# %%
# view first run
penn_20_run_1[0:366]
# Out:
#      year  day  cumulative_days  male_deer_population  female_deer_population  \
# 0       0    0                0                375000                 1125000
# 1       0    1                1                375000                 1125000
# 2       0    2                2                375000                 1125000
# 3       0    3                3                375000                 1125000
# 4       0    4                4                375000                 1125000
# ..    ...  ...              ...                   ...                     ...
# 361     0  361              361                463000                 1041000
# 362     0  362              362                463000                 1041000
# 363     0  363              363                463000                 1041000
# 364     0  364              364                463000                 1041000
# 365     0  365              365                463000                 1041000
#
# ...

# %%
# view second run
penn_20_run_2[0:366]
# Out:
#      year  day  cumulative_days  male_deer_population  female_deer_population  \
# 0       0    0                0                375000                 1125000
# 1       0    1                1                375000                 1125000
# 2       0    2                2                375000                 1125000
# 3       0    3                3                375000                 1125000
# 4       0    4                4                375000                 1125000
# ..    ...  ...              ...                   ...                     ...
# 361     0  361              361                485000                 1092000
# 362     0  362              362                485000                 1092000
# 363     0  363              363                485000                 1092000
# 364     0  364              364                485000                 1092000
# 365     0  365              365                485000                 1092000
#
# ...

# %%
# view third run
penn_20_run_3[0:366]
# Out:
#      year  day  cumulative_days  male_deer_population  female_deer_population  \
# 0       0    0                0                375000                 1125000
# 1       0    1                1                375000                 1125000
# 2       0    2                2                375000                 1125000
# 3       0    3                3                375000                 1125000
# 4       0    4                4                375000                 1125000
# ..    ...  ...              ...                   ...                     ...
# 361     0  361              361                494000                 1073000
# 362     0  362              362                494000                 1073000
# 363     0  363              363                494000                 1073000
# 364     0  364              364                494000                 1073000
# 365     0  365              365                494000                 1073000
#
# ...

# %%
# view fourth run
penn_20_run_4[0:366]
# Out:
#      year  day  cumulative_days  male_deer_population  female_deer_population  \
# 0       0    0                0                375000                 1125000
# 1       0    1                1                375000                 1125000
# 2       0    2                2                375000                 1125000
# 3       0    3                3                375000                 1125000
# 4       0    4                4                375000                 1125000
# ..    ...  ...              ...                   ...                     ...
# 361     0  361              361                463000                 1069000
# 362     0  362              362                463000                 1069000
# 363     0  363              363                463000                 1069000
# 364     0  364              364                463000                 1069000
# 365     0  365              365                463000                 1069000
#
# ...

# %%
# view fifth run
penn_20_run_5[0:366]
# Out:
#      year  day  cumulative_days  male_deer_population  female_deer_population  \
# 0       0    0                0                375000                 1125000
# 1       0    1                1                375000                 1125000
# 2       0    2                2                375000                 1125000
# 3       0    3                3                375000                 1125000
# 4       0    4                4                375000                 1125000
# ..    ...  ...              ...                   ...                     ...
# 361     0  361              361                486000                 1080000
# 362     0  362              362                486000                 1080000
# 363     0  363              363                486000                 1080000
# 364     0  364              364                486000                 1080000
# 365     0  365              365                486000                 1080000
#
# ...

# %%
# plot of the total deer population over time for all the five runs

fig, ax = plt.subplots()

ax.plot(penn_20_run_1['day'][1:366], penn_20_run_1['total_deer_population'][1:366], alpha=0.4, color='red', label='Run 1')
ax.plot(penn_20_run_2['day'][1:366], penn_20_run_2['total_deer_population'][1:366], alpha=0.4, color='blue', label='Run 2')
ax.plot(penn_20_run_3['day'][1:366], penn_20_run_3['total_deer_population'][1:366], alpha=0.4, color='green', label='Run 3')
ax.plot(penn_20_run_4['day'][1:366], penn_20_run_4['total_deer_population'][1:366], alpha=0.4, color='orange', label='Run 4')
ax.plot(penn_20_run_5['day'][1:366], penn_20_run_5['total_deer_population'][1:366], alpha=0.4, color='purple', label='Run 5')
ax.set_xlabel('Day')
ax.set_ylabel('Total Deer Population')
ax.legend()
plt.show()


# calculate the mean of the end population for all the five runs

mean_pop = statistics.mean([penn_20_run_1['total_deer_population'][365],penn_20_run_2['total_deer_population'][365],penn_20_run_3['total_deer_population'][365],penn_20_run_4['total_deer_population'][365],penn_20_run_5['total_deer_population'][365]])
print('The mean deer population at the end of 2019-2020 of the five runs is:', mean_pop)
# Out:
# The mean deer population at the end of 2019-2020 of the five runs is: 1549200

# %%
# plot of the total deer hit over time for all the five runs

fig, ax = plt.subplots()

ax.plot(penn_20_run_1['day'][1:366], penn_20_run_1['number_of_deer_hit'][1:366], alpha=0.4, color='red', label='Run 1')
ax.plot(penn_20_run_2['day'][1:366], penn_20_run_2['number_of_deer_hit'][1:366], alpha=0.4, color='blue', label='Run 2')
ax.plot(penn_20_run_3['day'][1:366], penn_20_run_3['number_of_deer_hit'][1:366], alpha=0.4, color='green', label='Run 3')
ax.plot(penn_20_run_4['day'][1:366], penn_20_run_4['number_of_deer_hit'][1:366], alpha=0.4, color='orange', label='Run 4')
ax.plot(penn_20_run_5['day'][1:366], penn_20_run_5['number_of_deer_hit'][1:366], alpha=0.4, color='purple', label='Run 5')
ax.set_xlabel('Day')
ax.set_ylabel('Total Deer Hit')
ax.legend()
plt.show()


# calculate the mean of the end population for all the five runs
mean_hit = statistics.mean([penn_20_run_1['number_of_deer_hit'][365],penn_20_run_2['number_of_deer_hit'][365],penn_20_run_3['number_of_deer_hit'][365],penn_20_run_4['number_of_deer_hit'][365],penn_20_run_5['number_of_deer_hit'][365]])

print('The mean deer hit at the end of 2019-2020 of the five runs is:', mean_hit)
# Out:
# The mean deer hit at the end of 2019-2020 of the five runs is: 4800

# %%
# plot of the total harvested deer over time for all the five runs

fig, ax = plt.subplots()

ax.plot(penn_20_run_1['day'][1:366], penn_20_run_1['harvested_deer'][1:366], alpha=0.4, color='red', label='Run 1')
ax.plot(penn_20_run_2['day'][1:366], penn_20_run_2['harvested_deer'][1:366], alpha=0.4, color='blue', label='Run 2')
ax.plot(penn_20_run_3['day'][1:366], penn_20_run_3['harvested_deer'][1:366], alpha=0.4, color='green', label='Run 3')
ax.plot(penn_20_run_4['day'][1:366], penn_20_run_4['harvested_deer'][1:366], alpha=0.4, color='orange', label='Run 4')
ax.plot(penn_20_run_5['day'][1:366], penn_20_run_5['harvested_deer'][1:366], alpha=0.4, color='purple', label='Run 5')
ax.set_xlabel('Day')
ax.set_ylabel('Total Harvested Deer')
ax.legend()
plt.show()


# calculate the mean of the total deer harvested for all the five runs
mean_har = statistics.mean([penn_20_run_1['harvested_deer'][365],penn_20_run_2['harvested_deer'][365],penn_20_run_3['harvested_deer'][365],penn_20_run_4['harvested_deer'][365],penn_20_run_5['harvested_deer'][365]])
print('The mean deer harvested at the end of 2019-2020 of the five runs is:', mean_har)
# Out:
# The mean deer harvested at the end of 2019-2020 of the five runs is: 367400

# %%
# End of year results:
print("Total deer population:", mean_pop)
print("Total female deer population:", statistics.mean([penn_20_run_1['female_deer_population'][365],penn_20_run_2['female_deer_population'][365],penn_20_run_3['female_deer_population'][365],penn_20_run_4['female_deer_population'][365],penn_20_run_5['female_deer_population'][365]]))
print("Total male deer population:",statistics.mean([penn_20_run_1['male_deer_population'][365],penn_20_run_2['male_deer_population'][365],penn_20_run_3['male_deer_population'][365],penn_20_run_4['male_deer_population'][365],penn_20_run_5['male_deer_population'][365]]))
print("Total deer hit:", mean_hit)
print("Total deer harvested:", mean_har)
# Out:
# Total deer population: 1549200
# Total female deer population: 1071000
# Total male deer population: 478200
# Total deer hit: 4800
# Total deer harvested: 367400

# %% [markdown]
# ### 2020-2021

# %%
penn_21_run_1 = pd.read_csv("2020-2021/penn_21_run_1.csv")
penn_21_run_2 = pd.read_csv("2020-2021/penn_21_run_2.csv")
penn_21_run_3 = pd.read_csv("2020-2021/penn_21_run_3.csv")
penn_21_run_4 = pd.read_csv("2020-2021/penn_21_run_4.csv")
penn_21_run_5 = pd.read_csv("2020-2021/penn_21_run_5.csv")

# %%
# view first run
penn_21_run_1[0:366]
# Out:
#      year  day  cumulative_days  male_deer_population  female_deer_population  \
# 0       0    0                0                478000                 1071000
# 1       0    1                1                478000                 1071000
# 2       0    2                2                478000                 1071000
# 3       0    3                3                478000                 1071000
# 4       0    4                4                478000                 1071000
# ..    ...  ...              ...                   ...                     ...
# 361     0  361              361                563000                 1041000
# 362     0  362              362                563000                 1041000
# 363     0  363              363                563000                 1041000
# 364     0  364              364                563000                 1041000
# 365     0  365              365                563000                 1041000
#
# ...

# %%
# view second run
penn_21_run_2[0:366]
# Out:
#      year  day  cumulative_days  male_deer_population  female_deer_population  \
# 0       0    0                0                478000                 1071000
# 1       0    1                1                478000                 1071000
# 2       0    2                2                478000                 1071000
# 3       0    3                3                478000                 1071000
# 4       0    4                4                478000                 1071000
# ..    ...  ...              ...                   ...                     ...
# 361     0  361              361                573000                 1061000
# 362     0  362              362                573000                 1061000
# 363     0  363              363                573000                 1061000
# 364     0  364              364                573000                 1061000
# 365     0  365              365                573000                 1061000
#
# ...

# %%
# view third run
penn_21_run_3[0:366]
# Out:
#      year  day  cumulative_days  male_deer_population  female_deer_population  \
# 0       0    0                0                478000                 1071000
# 1       0    1                1                478000                 1071000
# 2       0    2                2                478000                 1071000
# 3       0    3                3                478000                 1071000
# 4       0    4                4                478000                 1071000
# ..    ...  ...              ...                   ...                     ...
# 361     0  361              361                583000                 1071000
# 362     0  362              362                583000                 1071000
# 363     0  363              363                583000                 1071000
# 364     0  364              364                583000                 1071000
# 365     0  365              365                583000                 1071000
#
# ...

# %%
# view fourth run
penn_21_run_4[0:366]
# Out:
#      year  day  cumulative_days  male_deer_population  female_deer_population  \
# 0       0    0                0                478000                 1071000
# 1       0    1                1                478000                 1071000
# 2       0    2                2                478000                 1071000
# 3       0    3                3                478000                 1071000
# 4       0    4                4                478000                 1071000
# ..    ...  ...              ...                   ...                     ...
# 361     0  361              361                575000                 1040000
# 362     0  362              362                575000                 1040000
# 363     0  363              363                575000                 1040000
# 364     0  364              364                575000                 1040000
# 365     0  365              365                575000                 1040000
#
# ...

# %%
# view fifth run
penn_21_run_5[0:366]
# Out:
#      year  day  cumulative_days  male_deer_population  female_deer_population  \
# 0       0    0                0                478000                 1071000
# 1       0    1                1                478000                 1071000
# 2       0    2                2                478000                 1071000
# 3       0    3                3                478000                 1071000
# 4       0    4                4                478000                 1071000
# ..    ...  ...              ...                   ...                     ...
# 361     0  361              361                592000                 1074000
# 362     0  362              362                592000                 1074000
# 363     0  363              363                592000                 1074000
# 364     0  364              364                592000                 1074000
# 365     0  365              365                592000                 1074000
#
# ...

# %%
# plot of the total deer population over time for all the five runs

fig, ax = plt.subplots()

ax.plot(penn_21_run_1['day'][1:366], penn_21_run_1['total_deer_population'][1:366], alpha=0.4, color='red', label='Run 1')
ax.plot(penn_21_run_2['day'][1:366], penn_21_run_2['total_deer_population'][1:366], alpha=0.4, color='blue', label='Run 2')
ax.plot(penn_21_run_3['day'][1:366], penn_21_run_3['total_deer_population'][1:366], alpha=0.4, color='green', label='Run 3')
ax.plot(penn_21_run_4['day'][1:366], penn_21_run_4['total_deer_population'][1:366], alpha=0.4, color='orange', label='Run 4')
ax.plot(penn_21_run_5['day'][1:366], penn_21_run_5['total_deer_population'][1:366], alpha=0.4, color='purple', label='Run 5')
ax.set_xlabel('Day')
ax.set_ylabel('Total Deer Population')
ax.legend()
plt.show()


# calculate the mean of the end population for all the five runs

mean_pop = statistics.mean([penn_21_run_1['total_deer_population'][365],penn_21_run_2['total_deer_population'][365],penn_21_run_3['total_deer_population'][365],penn_21_run_4['total_deer_population'][365],penn_21_run_5['total_deer_population'][365]])
print('The mean deer population at the end of 2019-2020 of the five runs is:', mean_pop)
# Out:
# The mean deer population at the end of 2019-2020 of the five runs is: 1634600

# %%
# plot of the total deer hit over time for all the five runs

fig, ax = plt.subplots()

ax.plot(penn_21_run_1['day'][1:366], penn_21_run_1['number_of_deer_hit'][1:366], alpha=0.4, color='red', label='Run 1')
ax.plot(penn_21_run_2['day'][1:366], penn_21_run_2['number_of_deer_hit'][1:366], alpha=0.4, color='blue', label='Run 2')
ax.plot(penn_21_run_3['day'][1:366], penn_21_run_3['number_of_deer_hit'][1:366], alpha=0.4, color='green', label='Run 3')
ax.plot(penn_21_run_4['day'][1:366], penn_21_run_4['number_of_deer_hit'][1:366], alpha=0.4, color='orange', label='Run 4')
ax.plot(penn_21_run_5['day'][1:366], penn_21_run_5['number_of_deer_hit'][1:366], alpha=0.4, color='purple', label='Run 5')
ax.set_xlabel('Day')
ax.set_ylabel('Total Deer Hit')
ax.legend()
plt.show()


# calculate the mean of the end population for all the five runs
mean_hit = statistics.mean([penn_21_run_1['number_of_deer_hit'][365],penn_21_run_2['number_of_deer_hit'][365],penn_21_run_3['number_of_deer_hit'][365],penn_21_run_4['number_of_deer_hit'][365],penn_21_run_5['number_of_deer_hit'][365]])

print('The mean deer hit at the end of 2019-2020 of the five runs is:', mean_hit)
# Out:
# The mean deer hit at the end of 2019-2020 of the five runs is: 4400

# %%
# plot of the total harvested deer over time for all the five runs

fig, ax = plt.subplots()

ax.plot(penn_21_run_1['day'][1:366], penn_21_run_1['harvested_deer'][1:366], alpha=0.4, color='red', label='Run 1')
ax.plot(penn_21_run_2['day'][1:366], penn_21_run_2['harvested_deer'][1:366], alpha=0.4, color='blue', label='Run 2')
ax.plot(penn_21_run_3['day'][1:366], penn_21_run_3['harvested_deer'][1:366], alpha=0.4, color='green', label='Run 3')
ax.plot(penn_21_run_4['day'][1:366], penn_21_run_4['harvested_deer'][1:366], alpha=0.4, color='orange', label='Run 4')
ax.plot(penn_21_run_5['day'][1:366], penn_21_run_5['harvested_deer'][1:366], alpha=0.4, color='purple', label='Run 5')
ax.set_xlabel('Day')
ax.set_ylabel('Total Harvested Deer')
ax.legend()
plt.show()


# calculate the mean of the total deer harvested for all the five runs
mean_har = statistics.mean([penn_21_run_1['harvested_deer'][365],penn_21_run_2['harvested_deer'][365],penn_21_run_3['harvested_deer'][365],penn_21_run_4['harvested_deer'][365],penn_21_run_5['harvested_deer'][365]])
print('The mean deer harvested at the end of 2019-2020 of the five runs is:', mean_har)
# Out:
# The mean deer harvested at the end of 2019-2020 of the five runs is: 406000

# %%
# End of year results:
print("Total deer population:", mean_pop)
print("Total female deer population:", statistics.mean([penn_21_run_1['female_deer_population'][365],penn_21_run_2['female_deer_population'][365],penn_21_run_3['female_deer_population'][365],penn_21_run_4['female_deer_population'][365],penn_21_run_5['female_deer_population'][365]]))
print("Total male deer population:",statistics.mean([penn_21_run_1['male_deer_population'][365],penn_21_run_2['male_deer_population'][365],penn_21_run_3['male_deer_population'][365],penn_21_run_4['male_deer_population'][365],penn_21_run_5['male_deer_population'][365]]))
print("Total deer hit:", mean_hit)
print("Total deer harvested:", mean_har)
# Out:
# Total deer population: 1634600
# Total female deer population: 1057400
# Total male deer population: 577200
# Total deer hit: 4400
# Total deer harvested: 406000

# %% [markdown]
# ### 2019-2020 & 2020-2021

# %%
# getting the averages of the 5 runs in 2019-2020
penn_20_averages = pd.DataFrame()
penn_20_averages['total_deer_population'] = (penn_20_run_1['total_deer_population'][1:366] + penn_20_run_2['total_deer_population'][1:366] + penn_20_run_3['total_deer_population'][1:366] + penn_20_run_4['total_deer_population'][1:366] + penn_20_run_5['total_deer_population'][1:366])/5 
penn_20_averages['number_of_deer_hit'] = (penn_20_run_1['number_of_deer_hit'][1:366] + penn_20_run_2['number_of_deer_hit'][1:366] + penn_20_run_3['number_of_deer_hit'][1:366] + penn_20_run_4['number_of_deer_hit'][1:366] + penn_20_run_5['number_of_deer_hit'][1:366])/5 
penn_20_averages['harvested_deer'] = (penn_20_run_1['harvested_deer'][1:366] + penn_20_run_2['harvested_deer'][1:366] + penn_20_run_3['harvested_deer'][1:366] + penn_20_run_4['harvested_deer'][1:366] + penn_20_run_5['harvested_deer'][1:366])/5 

penn_20_averages
# Out:
#      total_deer_population  number_of_deer_hit  harvested_deer
# 1                1500000.0                 0.0             0.0
# 2                1500000.0                 0.0             0.0
# 3                1500000.0                 0.0             0.0
# 4                1500000.0                 0.0             0.0
# 5                1500000.0                 0.0             0.0
# ..                     ...                 ...             ...
# 361              1549200.0              4800.0        367400.0
# 362              1549200.0              4800.0        367400.0
# 363              1549200.0              4800.0        367400.0
# 364              1549200.0              4800.0        367400.0
# 365              1549200.0              4800.0        367400.0
#
# [365 rows x 3 columns]

# %%
# getting the averages of the 5 runs in 2020-2021
penn_21_averages = pd.DataFrame()
penn_21_averages['total_deer_population'] = (penn_21_run_1['total_deer_population'][1:366] + penn_21_run_2['total_deer_population'][1:366] + penn_21_run_3['total_deer_population'][1:366] + penn_21_run_4['total_deer_population'][1:366] + penn_21_run_5['total_deer_population'][1:366])/5 
penn_21_averages['number_of_deer_hit'] = (penn_21_run_1['number_of_deer_hit'][1:366] + penn_21_run_2['number_of_deer_hit'][1:366] + penn_21_run_3['number_of_deer_hit'][1:366] + penn_21_run_4['number_of_deer_hit'][1:366] + penn_21_run_5['number_of_deer_hit'][1:366])/5 
penn_21_averages['harvested_deer'] = (penn_21_run_1['harvested_deer'][1:366] + penn_21_run_2['harvested_deer'][1:366] + penn_21_run_3['harvested_deer'][1:366] + penn_21_run_4['harvested_deer'][1:366] + penn_21_run_5['harvested_deer'][1:366])/5 

penn_21_averages
# Out:
#      total_deer_population  number_of_deer_hit  harvested_deer
# 1                1549000.0                 0.0             0.0
# 2                1549000.0                 0.0             0.0
# 3                1549000.0                 0.0             0.0
# 4                1549000.0                 0.0             0.0
# 5                1549000.0                 0.0             0.0
# ..                     ...                 ...             ...
# 361              1634600.0              4400.0        406000.0
# 362              1634600.0              4400.0        406000.0
# 363              1634600.0              4400.0        406000.0
# 364              1634600.0              4400.0        406000.0
# 365              1634600.0              4400.0        406000.0
#
# [365 rows x 3 columns]

# %%
# plot of the total deer population of 2019-2020 (in red) & 2020-2021 (in blue)
fig, ax = plt.subplots()

ax.plot(penn_20_averages['total_deer_population'], alpha=0.4, color='red', label='2019-2020')
ax.plot(penn_21_averages['total_deer_population'], alpha=0.4, color='blue', label='2020-2021')

ax.set_xlabel('Day')
ax.set_ylabel('Total Deer Population')
ax.legend()
plt.show()

# %%
# plot of the number of deer hit in 2019-2020 (in red) & 2020-2021 (in blue) and also the true value from the data
fig, ax = plt.subplots()

ax.plot(penn_20_averages['number_of_deer_hit'], alpha=0.4, color='red', label='2019-2020')
ax.plot(365, 4332, marker="o", markersize=5, markerfacecolor="red")
ax.annotate("Actual value 2019-2020", (365, 4332))
ax.plot(penn_21_averages['number_of_deer_hit'], alpha=0.4, color='blue', label='2020-2021')
ax.plot(365, 4343, marker="o", markersize=5, markerfacecolor="blue")
ax.annotate("Actual value 2020-2021", (365, 4100))

ax.set_xlabel('Day')
ax.set_ylabel('Number of Deer Hit')
ax.legend()
plt.show()

# %%
# plot of harvested deer in 2019-2020 (in red) & 2020-2021 (in blue) and also the true value from the data
fig, ax = plt.subplots()

ax.plot(penn_20_averages['harvested_deer'], alpha=0.4, color='red', label='2019-2020')
ax.plot(365, 389431, marker="o", markersize=5, markerfacecolor="red")
ax.annotate("Actual value 2019-2020", (365, 389431))
ax.plot(penn_21_averages['harvested_deer'], alpha=0.4, color='blue', label='2020-2021')
ax.plot(365, 435180, marker="o", markersize=5, markerfacecolor="blue")
ax.annotate("Actual value 2020-2021", (365, 435180))

ax.set_xlabel('Day')
ax.set_ylabel('Harvested Deer')
ax.legend()
plt.show()
